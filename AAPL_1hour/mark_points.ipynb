# %%
import pandas as pd

alpha = 0.01

def mark_min_points(df):
    df['is_min'] = 0
    for i in range(4, len(df) - 5):
        if df.iloc[i]['open'] > df.iloc[i]['close']:
            continue
        minL = min(min(df.iloc[i-4:i]['close']), min(df.iloc[i-4:i]['open']))
        minR = min(min(df.iloc[i+1:i+5]['open']), min(df.iloc[i+1:i+5]['close']))
        if df.iloc[i]['open'] > minL or df.iloc[i]['open'] > minR:
            continue
        if df.iloc[i]['open'] <= df.iloc[i-4]['open'] * (1 - alpha) and df.iloc[i]['open'] <= df.iloc[i+4]['close'] * (1 - alpha):
            df.loc[df.index[i], "is_min"] = 1
    return df

def mark_max_points(df):
    df['is_max'] = 0
    for i in range(4, len(df) - 5):
        if df.iloc[i]['open'] < df.iloc[i]['close']:
            continue
        maxL = max(max(df.iloc[i-4:i]['close']), max(df.iloc[i-4:i]['open']))
        maxR = max(max(df.iloc[i+1:i+5]['open']), max(df.iloc[i+1:i+5]['close']))
        if df.iloc[i]['open'] < maxL or df.iloc[i]['open'] < maxR:
            continue
        if df.iloc[i]['open'] >= df.iloc[i-4]['open'] * (1 + alpha) and df.iloc[i]['open'] >= df.iloc[i+4]['close'] * (1 + alpha):
            df.loc[df.index[i], "is_max"] = 1
    return df

# %%
df_name = "AAPL_1hour"
df = pd.read_csv(f'../datasets/{df_name}.csv')
df["datetime"] = pd.to_datetime(df["datetime"])
df = df.set_index("datetime")
df.shape
# Out:
# (10000, 5)

# %%
df = mark_min_points(df)
df = mark_max_points(df)
df[(df['is_min'] == 1) | (df['is_max'] == 1)]
# Out:
#                           open       high        low      close    volume  \
# datetime
# 2020-06-15 13:00:00   83.31250   84.19750   83.14750   84.04000   1494468
# 2020-06-19 13:00:00   88.86748   89.14000   88.61558   88.75355   3038444
# 2020-06-29 13:30:00   88.31250   89.38000   87.82000   89.30250  35821384
# 2020-07-13 15:30:00   99.90500   99.90500   99.24000   99.44750         0
# 2020-07-14 14:30:00   94.75500   95.42500   94.54000   95.27000         0
# ...                        ...        ...        ...        ...       ...
# 2025-10-31 13:30:00  276.98999  277.32001  269.16000  270.38000  17228178
# 2025-11-20 15:30:00  273.91000  274.73001  271.62000  271.78000   2856925
# 2025-11-21 14:30:00  265.88000  270.45001  265.82001  269.85001  10658658
# 2026-01-08 16:30:00  256.10999  258.60001  255.97000  256.70901   3892484
# 2026-02-05 18:30:00  274.26001  277.57001  274.11499  277.04501   2995492
#
#                      is_min  is_max
# datetime
# 2020-06-15 13:00:00       1       0
# 2020-06-19 13:00:00       0       1
# 2020-06-29 13:30:00       1       0
# 2020-07-13 15:30:00       0       1
# 2020-07-14 14:30:00       1       0
# ...                     ...     ...
# 2025-10-31 13:30:00       0       1
# 2025-11-20 15:30:00       0       1
# 2025-11-21 14:30:00       1       0
# 2026-01-08 16:30:00       1       0
# 2026-02-05 18:30:00       1       0
#
# [203 rows x 7 columns]

# %%
df.to_csv(f'../datasets/{df_name}_marked.csv')
