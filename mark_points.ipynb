# %%
import pandas as pd

alpha = 0.001

def mark_min_points(df):
    df['is_min'] = 0
    for i in range(4, len(df) - 5):
        if df.iloc[i]['open'] > df.iloc[i]['close']:
            continue
        minL = min(min(df.iloc[i-4:i]['close']), min(df.iloc[i-4:i]['open']))
        minR = min(min(df.iloc[i+1:i+5]['open']), min(df.iloc[i+1:i+5]['close']))
        if df.iloc[i]['open'] > minL or df.iloc[i]['open'] > minR:
            continue
        if df.iloc[i]['open'] <= df.iloc[i-4]['open'] * (1 - alpha) and df.iloc[i]['open'] <= df.iloc[i+4]['close'] * (1 - alpha):
            df.loc[df.index[i], "is_min"] = 1
    return df

def mark_max_points(df):
    df['is_max'] = 0
    for i in range(4, len(df) - 5):
        if df.iloc[i]['open'] < df.iloc[i]['close']:
            continue
        maxL = max(max(df.iloc[i-4:i]['close']), max(df.iloc[i-4:i]['open']))
        maxR = max(max(df.iloc[i+1:i+5]['open']), max(df.iloc[i+1:i+5]['close']))
        if df.iloc[i]['open'] < maxL or df.iloc[i]['open'] < maxR:
            continue
        if df.iloc[i]['open'] >= df.iloc[i-4]['open'] * (1 + alpha) and df.iloc[i]['open'] >= df.iloc[i+4]['close'] * (1 + alpha):
            df.loc[df.index[i], "is_max"] = 1
    return df

# %%
df_name = "AAPL_15min"
df = pd.read_csv(f'datasets/{df_name}.csv')
df["datetime"] = pd.to_datetime(df["datetime"])
df = df.set_index("datetime")
df.shape
# Out:
# (10000, 5)

# %%
df = mark_min_points(df)
df = mark_max_points(df)
df[(df['is_min'] == 1) | (df['is_max'] == 1)]
# Out:
#                           open       high        low      close    volume  \
# datetime
# 2024-07-31 17:45:00  221.73000  222.45000  221.67000  222.17000    723725
# 2024-08-01 13:30:00  224.37000  224.45050  222.56000  223.05000   4110658
# 2024-08-02 13:45:00  223.60001  224.41499  222.10010  223.23000   5926851
# 2024-08-05 13:30:00  199.14000  210.00000  196.21001  208.55000  27409767
# 2024-08-05 16:30:00  212.62000  212.64999  210.55009  210.78999   1787765
# ...                        ...        ...        ...        ...       ...
# 2026-02-10 17:00:00  273.29001  273.79999  273.26999  273.48001    474275
# 2026-02-11 16:00:00  279.75500  279.98001  278.81000  279.67499   1070854
# 2026-02-11 19:30:00  279.57999  279.59000  278.57999  278.87000    499321
# 2026-02-12 20:00:00  262.06000  262.48999  261.60001  262.00000    952586
# 2026-02-13 17:45:00  260.12000  260.17999  259.02499  259.04501    831719
#
#                      is_min  is_max
# datetime
# 2024-07-31 17:45:00       1       0
# 2024-08-01 13:30:00       0       1
# 2024-08-02 13:45:00       0       1
# 2024-08-05 13:30:00       1       0
# 2024-08-05 16:30:00       0       1
# ...                     ...     ...
# 2026-02-10 17:00:00       1       0
# 2026-02-11 16:00:00       0       1
# 2026-02-11 19:30:00       0       1
# 2026-02-12 20:00:00       0       1
# 2026-02-13 17:45:00       0       1
#
# [657 rows x 7 columns]

# %%
df.to_csv(f'datasets/{df_name}_marked.csv')
