# %%
import pandas as pd

alpha = 0.002

def mark_min_points(df):
    df['is_min'] = 0
    for i in range(4, len(df) - 5):
        if df.iloc[i]['open'] > df.iloc[i]['close']:
            continue
        minL = min(min(df.iloc[i-4:i]['close']), min(df.iloc[i-4:i]['open']))
        minR = min(min(df.iloc[i+1:i+5]['open']), min(df.iloc[i+1:i+5]['close']))
        if df.iloc[i]['open'] > minL or df.iloc[i]['open'] > minR:
            continue
        if df.iloc[i]['open'] <= df.iloc[i-4]['open'] * (1 - alpha) and df.iloc[i]['open'] <= df.iloc[i+4]['close'] * (1 - alpha):
            df.loc[df.index[i], "is_min"] = 1
    return df

def mark_max_points(df):
    df['is_max'] = 0
    for i in range(4, len(df) - 5):
        if df.iloc[i]['open'] < df.iloc[i]['close']:
            continue
        maxL = max(max(df.iloc[i-4:i]['close']), max(df.iloc[i-4:i]['open']))
        maxR = max(max(df.iloc[i+1:i+5]['open']), max(df.iloc[i+1:i+5]['close']))
        if df.iloc[i]['open'] < maxL or df.iloc[i]['open'] < maxR:
            continue
        if df.iloc[i]['open'] >= df.iloc[i-4]['open'] * (1 + alpha) and df.iloc[i]['open'] >= df.iloc[i+4]['close'] * (1 + alpha):
            df.loc[df.index[i], "is_max"] = 1
    return df

# %%
df_name = "AAPL_5min"
df = pd.read_csv(f'../datasets/{df_name}.csv')
df["datetime"] = pd.to_datetime(df["datetime"])
df = df.set_index("datetime")
df.shape
# Out:
# (10000, 5)

# %%
df = mark_min_points(df)
df = mark_max_points(df)
df[(df['is_min'] == 1) | (df['is_max'] == 1)]
# Out:
#                           open       high        low      close   volume  \
# datetime
# 2025-08-11 19:55:00  226.78999  227.30000  226.64000  227.20500  2895039
# 2025-08-12 13:35:00  229.83000  229.93990  228.39999  228.55000  1178023
# 2025-08-12 15:20:00  230.05000  230.06000  229.58000  229.59100   543169
# 2025-08-13 14:55:00  234.32001  234.55000  233.22000  233.60001  1253668
# 2025-08-13 15:15:00  231.84500  232.62000  231.67999  232.42909   946014
# ...                        ...        ...        ...        ...      ...
# 2026-02-11 20:45:00  276.28140  276.35001  275.94000  276.05499   201723
# 2026-02-12 15:35:00  271.60001  271.73999  271.19000  271.54999   300214
# 2026-02-12 18:20:00  260.31500  261.78000  260.31000  261.73999   549298
# 2026-02-12 20:55:00  262.45999  262.51001  261.54001  261.59000  2626511
# 2026-02-13 15:35:00  261.07999  261.48999  259.95001  259.98001   363361
#
#                      is_min  is_max
# datetime
# 2025-08-11 19:55:00       1       0
# 2025-08-12 13:35:00       0       1
# 2025-08-12 15:20:00       0       1
# 2025-08-13 14:55:00       0       1
# 2025-08-13 15:15:00       1       0
# ...                     ...     ...
# 2026-02-11 20:45:00       0       1
# 2026-02-12 15:35:00       0       1
# 2026-02-12 18:20:00       1       0
# 2026-02-12 20:55:00       0       1
# 2026-02-13 15:35:00       0       1
#
# [238 rows x 7 columns]

# %%
df.to_csv(f'../datasets/{df_name}_marked.csv')
